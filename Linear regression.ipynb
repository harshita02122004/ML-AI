# %% [markdown]
# <a href="https://colab.research.google.com/github/harshita02122004/ML-AI/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data (2).csv')

# %%
df.head(6)
# Out:
#    feature1  feature2  feature3     target
# 0 -0.570563  1.420342  0.495580  -9.763182
# 1 -0.990563  0.556965  1.045064 -24.029355
# 2 -0.674728  0.150617  1.774645  45.616421
# 3  0.388250 -0.387127 -0.110229  34.135737
# 4  1.167882 -0.024104  0.145063  86.663647
# 5 -0.889889 -1.580945 -0.422793 -77.897356

# %%
df.tail(11)
# Out:
#      feature1  feature2  feature3      target
# 189 -1.622461 -1.235637 -0.129361 -152.633225
# 190  1.193253 -1.075724  0.137916  109.330606
# 191 -0.349035  0.252825  1.990738  155.186749
# 192 -1.064195  0.437947  0.152946  -59.732161
# 193  0.006220 -0.826004 -0.610250  -44.273582
# 194 -0.018628  0.483529  0.151130   15.394978
# 195  0.255081 -0.231497 -0.239632   38.067836
# 196  0.276068 -0.648411 -0.077441   12.812755
# 197  0.122250 -1.157383  0.765721   70.454115
# 198 -0.914822 -0.897140 -0.784205  -93.235783
# 199  0.090717 -2.217418 -0.892406  -42.772129

# %%
df.describe()
# Out:
#          feature1    feature2    feature3      target
# count  200.000000  200.000000  200.000000  200.000000
# mean     0.019595   -0.045539    0.048697    4.323508
# std      1.041478    1.057713    0.974019   97.258970
# min     -2.915738   -2.983970   -2.272244 -257.063427
# 25%     -0.647775   -0.810995   -0.650268  -60.735485
# 50%      0.007320    0.013617   -0.078591    2.991268
# 75%      0.704479    0.680593    0.729907   76.404521
# max      3.314304    2.676112    2.811878  290.546161

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   feature1  200 non-null    float64
#  1   feature2  200 non-null    float64
#  2   feature3  200 non-null    float64
#  3   target    200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
df.shape
# Out:
# (200, 4)

# %%
X = df.iloc[:,0:3].values
y = df.iloc[:,-1].values

# %%
X1 = df['feature1'].values.reshape(-1,1)
y1=df['target'].values

# %%
X1
# Out:
# array([[-5.70562824e-01],
#        [-9.90562704e-01],
#        [-6.74727510e-01],
#        [ 3.88250414e-01],
#        [ 1.16788229e+00],
#        [-8.89888979e-01],
#        [-2.68510868e+00],
#        [ 6.63187770e-01],
#        [ 3.19196176e-01],
#        [-3.48368316e-01],
#        [-6.37134863e-01],
#        [ 1.11594518e+00],
#        [-6.89599657e-01],
#        [ 2.07087853e+00],
#        [-7.12849796e-01],
#        [ 8.87925723e-01],
#        [-2.94033248e-01],
#        [-1.47394283e+00],
#        [-1.35804520e+00],
#        [ 2.87657229e-01],
#        [-6.38790896e-01],
#        [-7.68836350e-01],
#        [-6.26414503e-01],
#        [-5.45359948e-01],
#        [ 2.94532137e-01],
#        [-1.02523943e-01],
#        [-1.24173986e+00],
#        [ 1.43069737e+00],
#        [-1.31386475e+00],
#        [-3.84663176e-01],
#        [-4.64668721e-01],
#        [-1.11830068e+00],
#        [-1.95576713e+00],
#        [ 1.84790906e+00],
#        [ 1.28007821e-01],
# ...

# %%
y1
# Out:
# array([  -9.76318213,  -24.02935493,   45.61642069,   34.13573658,
#          86.66364674,  -77.89735638,  -75.23160582,  -57.49271113,
#         -54.17628622,   29.46983531,  -87.07697894,   61.49707765,
#         -87.1908553 ,  189.52586717, -105.60940906,   72.93452847,
#          33.37559704, -108.0026368 , -127.03270151,  -97.32244317,
#         -56.51293004,  -61.6929032 ,  -46.54502761,  -55.46277415,
#          98.27590634,   53.88321804,  -69.66191612,  143.07902342,
#        -114.61997528,   31.85127955,  -44.39024034,    1.48968394,
#         -88.71622065,   87.12681822,  -17.28585002,  150.20169579,
#         -71.41503479, -139.82571896,  190.13399327,  126.78997841,
#         191.14039956,  -15.88018358,   79.0476178 ,   32.44367679,
#          43.23159853,  -34.70291861,  -94.49899703,   92.90733739,
#         -49.79965934, -257.06342658,  -28.33835823,   52.78981793,
#        -114.24973574,   31.88367296,   80.14978081,   85.36236114,
# ...

# %%
impt pandaors as pd

data = [[50, True], [40, False], [30, False]]

df = pd.DataFrame(data)

print(df.iloc[1, 1])
# Out:
#   File "<ipython-input-39-4d1af5ee6b95>", line 1
#     impt pandaors as pd
#          ^
# SyntaxError: invalid syntax
